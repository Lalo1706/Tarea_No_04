# %%
from math import sqrt

def ecuacion(a, b, c):
    determinante = b**2 - 4*a*c

    if determinante > 0:
        x_1 = (-b + sqrt(determinante)) / (2*a)
        x_2 = (-b - sqrt(determinante)) / (2*a)
        return x_1, x_2

    elif determinante == 0:
        x_1 = -b  / (2*a)
        return (x_1,)
    else:
        return tuple ()


print("Ingrese sus valores")

a = int(input("Valor de a "))
b = int(input("Valor de b "))
c = int(input("Valor de c "))

print("Resultado (x1, x2)", ecuacion(a, b, c))
# Out:
# Ingrese sus valores
# Valor de a 7
# Valor de b -13
# Valor de c 6
# Resultado (x1, x2) (1.0, 0.8571428571428571)
